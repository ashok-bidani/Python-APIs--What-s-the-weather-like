# %% [markdown]
# #### Import Dependencies

# %%
import random
import requests
import csv
import pandas as pd
import matplotlib.pyplot as plt

# Install and import the citipy package. This package will output the nearest city to a specific pair of geographical
# coordinates. It is very important for this project.
import sys
# !{sys.executable} -m pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\ashok\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\ashok\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# #### Save config information.

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
api_key = "febde43dfe4affe5e81fe677f8e0a7e3"

# %% [markdown]
# #### Generate 500 cities for data analysis

# %%
# Latitude limits for the analysis are the full -90 degrees and 90 degrees.
# Longitude limits are -180 degrees and 180 degrees.
lat_min = -90
lat_max = 90

long_min = -180
long_max = 180

# Set a counter and create an empty list for holding the city and country
# information
counter = 0
cities = []
countries = []

#Generate pseudo-random latitude and longitude coordinates
while counter < 560:
    lat = random.uniform(lat_min, lat_max)
    long = random.uniform(long_min, long_max)

#Pick the nearest city to those latitude and longitude values
    loc = citipy.nearest_city(lat, long)
    city = loc.city_name
    country = loc.country_code
    if city: 
        if city not in cities:
            cities.append(city)
            countries.append(country)
            counter = counter + 1
        else:
            pass

# %% [markdown]
# #### Perform a query to OpenWeatherMap site for each city

# %%
# What I want is to run a loop for 500 individual cities, where for each
# city I pull the weather data and then move on to the next city. Unfortunately
# the Citipy database is more extensive than OpenWeatherMap, so I end up with 
# fewer than 500 cities in my weather data if I simply perform 500 queries. To
# to offset and reconcile this, I selected more than 500 cities from the CitiPy
# app and then performed queries on each of them, resulting in CLOSE TO 500 net
# data points.

#The following code is adapted from the exercise Ins_OpenWeatherDataFrame:

# %%
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Set up lists to hold reponse info

city_name = []
lat = []
maxtemp = []
humid = []
cloud = []
wind_spd = []

counter = 0

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        print(f"checking {city} (city number {counter}) at url {query_url + city}")
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        maxtemp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_spd.append(response['wind']['speed'])
        counter = counter + 1
    except:
        print("City not found")
        pass
# Out:
# checking pushkar (city number 0) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pushkar
# checking debre sina (city number 1) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=debre sina
# checking vestmannaeyjar (city number 2) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vestmannaeyjar
# checking nikolskoye (city number 3) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nikolskoye
# checking carnarvon (city number 4) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=carnarvon
# checking khoriyion (city number 5) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=khoriyion
# City not found
# checking ushuaia (city number 5) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ushuaia
# checking hermanus (city number 6) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hermanus
# checking puerto ayora (city number 7) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=puerto ayora
# checking ekhabi (city number 8) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ekhabi
# checking busselton (city number 9) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=busselton
# checking rikitea (city number 10) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=rikitea
# checking yantal (city number 11) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yantal
# checking mataura (city number 12) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mataura
# checking hithadhoo (city number 13) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hithadhoo
# checking cape town (city number 14) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=cape town
# checking otradnoye (city number 15) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=otradnoye
# checking isangel (city number 16) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=isangel
# checking georgetown (city number 17) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=georgetown
# checking mayo (city number 18) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mayo
# checking talnakh (city number 19) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=talnakh
# checking san patricio (city number 20) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=san patricio
# checking sorland (city number 21) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sorland
# checking punta arenas (city number 22) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=punta arenas
# checking castro (city number 23) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=castro
# checking saint-philippe (city number 24) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-philippe
# checking pevek (city number 25) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pevek
# checking saint-leu (city number 26) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-leu
# checking la ronge (city number 27) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=la ronge
# checking hobart (city number 28) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hobart
# checking khandbari (city number 29) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=khandbari
# checking karauzyak (city number 30) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=karauzyak
# City not found
# checking tarudant (city number 30) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tarudant
# City not found
# checking lebu (city number 30) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lebu
# checking jamestown (city number 31) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=jamestown
# checking ola (city number 32) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ola
# checking beloha (city number 33) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=beloha
# checking tashara (city number 34) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tashara
# checking dingle (city number 35) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dingle
# checking cherskiy (city number 36) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=cherskiy
# checking kenitra (city number 37) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kenitra
# checking santo domingo (city number 38) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=santo domingo
# checking bethel (city number 39) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bethel
# checking kutum (city number 40) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kutum
# checking tiksi (city number 41) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tiksi
# checking albany (city number 42) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=albany
# checking tignere (city number 43) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tignere
# checking port hedland (city number 44) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=port hedland
# checking quatre cocos (city number 45) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=quatre cocos
# checking fairmont (city number 46) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=fairmont
# checking muros (city number 47) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=muros
# checking port alfred (city number 48) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=port alfred
# checking bredasdorp (city number 49) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bredasdorp
# checking dikson (city number 50) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dikson
# checking sao joao da barra (city number 51) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sao joao da barra
# checking kodiak (city number 52) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kodiak
# checking kapaa (city number 53) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kapaa
# checking berlevag (city number 54) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=berlevag
# checking balkanabat (city number 55) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=balkanabat
# checking butaritari (city number 56) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=butaritari
# checking mount gambier (city number 57) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mount gambier
# checking kargil (city number 58) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kargil
# checking tilichiki (city number 59) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tilichiki
# checking iralaya (city number 60) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=iralaya
# checking trelew (city number 61) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=trelew
# checking pisco (city number 62) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pisco
# checking kruisfontein (city number 63) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kruisfontein
# checking vaini (city number 64) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vaini
# checking taolanaro (city number 65) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=taolanaro
# City not found
# checking tuktoyaktuk (city number 65) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tuktoyaktuk
# checking nemuro (city number 66) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nemuro
# checking namatanai (city number 67) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=namatanai
# checking mar del plata (city number 68) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mar del plata
# checking attawapiskat (city number 69) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=attawapiskat
# City not found
# checking bawku (city number 69) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bawku
# checking sao felix do xingu (city number 70) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sao felix do xingu
# checking avarua (city number 71) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=avarua
# checking zhigansk (city number 72) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=zhigansk
# checking puerto penasco (city number 73) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=puerto penasco
# checking kavieng (city number 74) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kavieng
# checking strezhevoy (city number 75) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=strezhevoy
# checking ust-kuyga (city number 76) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ust-kuyga
# checking ketchikan (city number 77) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ketchikan
# checking moerai (city number 78) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=moerai
# checking provideniya (city number 79) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=provideniya
# checking castle rock (city number 80) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=castle rock
# checking mehamn (city number 81) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mehamn
# checking illoqqortoormiut (city number 82) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=illoqqortoormiut
# City not found
# checking ancud (city number 82) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ancud
# checking yate (city number 83) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yate
# checking inuvik (city number 84) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=inuvik
# checking teofilo otoni (city number 85) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=teofilo otoni
# checking dunedin (city number 86) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dunedin
# checking chuy (city number 87) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chuy
# checking tadine (city number 88) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tadine
# checking ribeira grande (city number 89) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ribeira grande
# checking korla (city number 90) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=korla
# City not found
# checking tacuarembo (city number 90) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tacuarembo
# checking ponta do sol (city number 91) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ponta do sol
# checking tiarei (city number 92) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tiarei
# checking harrisonburg (city number 93) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=harrisonburg
# checking belushya guba (city number 94) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=belushya guba
# City not found
# checking barrow (city number 94) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=barrow
# checking hofn (city number 95) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hofn
# checking ixtapa (city number 96) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ixtapa
# checking husavik (city number 97) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=husavik
# checking antalaha (city number 98) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=antalaha
# checking east london (city number 99) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=east london
# checking micheweni (city number 100) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=micheweni
# checking turtas (city number 101) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=turtas
# checking qui nhon (city number 102) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=qui nhon
# City not found
# checking numan (city number 102) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=numan
# checking sentyabrskiy (city number 103) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sentyabrskiy
# City not found
# checking alice springs (city number 103) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=alice springs
# checking pasni (city number 104) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pasni
# checking thompson (city number 105) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=thompson
# checking unirea (city number 106) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=unirea
# checking broome (city number 107) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=broome
# checking kokoda (city number 108) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kokoda
# checking tabou (city number 109) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tabou
# checking port elizabeth (city number 110) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=port elizabeth
# checking constitucion (city number 111) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=constitucion
# checking tsihombe (city number 112) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tsihombe
# City not found
# checking gamba (city number 112) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=gamba
# checking bismarck (city number 113) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bismarck
# checking grindavik (city number 114) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=grindavik
# checking saint-ambroise (city number 115) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-ambroise
# checking nome (city number 116) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nome
# checking tasiilaq (city number 117) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tasiilaq
# checking new norfolk (city number 118) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=new norfolk
# checking atuona (city number 119) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=atuona
# checking nanortalik (city number 120) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nanortalik
# checking tamworth (city number 121) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tamworth
# checking upernavik (city number 122) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=upernavik
# checking halifax (city number 123) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=halifax
# checking puro (city number 124) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=puro
# checking saldanha (city number 125) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saldanha
# checking souillac (city number 126) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=souillac
# checking hilo (city number 127) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hilo
# checking ziro (city number 128) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ziro
# checking zhezkazgan (city number 129) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=zhezkazgan
# checking jiayuguan (city number 130) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=jiayuguan
# checking shache (city number 131) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=shache
# checking salalah (city number 132) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=salalah
# checking rajshahi (city number 133) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=rajshahi
# checking stephenville crossing (city number 134) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=stephenville crossing
# checking guerrero negro (city number 135) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=guerrero negro
# checking chardara (city number 136) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chardara
# City not found
# checking taoudenni (city number 136) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=taoudenni
# checking vaitupu (city number 137) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vaitupu
# City not found
# checking komsomolskiy (city number 137) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=komsomolskiy
# checking portobelo (city number 138) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=portobelo
# checking maharajganj (city number 139) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=maharajganj
# checking bilibino (city number 140) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bilibino
# checking amderma (city number 141) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=amderma
# City not found
# checking papayal (city number 141) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=papayal
# checking sitka (city number 142) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sitka
# checking pacific grove (city number 143) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pacific grove
# checking gambela (city number 144) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=gambela
# checking kasongo-lunda (city number 145) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kasongo-lunda
# checking phrae (city number 146) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=phrae
# checking oussouye (city number 147) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=oussouye
# checking mys shmidta (city number 148) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mys shmidta
# City not found
# checking san luis (city number 148) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=san luis
# checking dordrecht (city number 149) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dordrecht
# checking moose factory (city number 150) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=moose factory
# checking san juan de flores (city number 151) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=san juan de flores
# checking yuma (city number 152) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yuma
# checking yellowknife (city number 153) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yellowknife
# checking hun (city number 154) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hun
# checking bluff (city number 155) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bluff
# checking nyimba (city number 156) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nyimba
# checking vao (city number 157) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vao
# checking tatvan (city number 158) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tatvan
# checking pailitas (city number 159) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pailitas
# checking bilma (city number 160) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bilma
# checking gospic (city number 161) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=gospic
# checking kijang (city number 162) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kijang
# checking hobyo (city number 163) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hobyo
# checking wolnzach (city number 164) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=wolnzach
# checking belaya gora (city number 165) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=belaya gora
# checking tahoua (city number 166) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tahoua
# checking san cristobal (city number 167) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=san cristobal
# checking lavrentiya (city number 168) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lavrentiya
# checking kandra (city number 169) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kandra
# checking broken hill (city number 170) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=broken hill
# checking severo-kurilsk (city number 171) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=severo-kurilsk
# checking wanaka (city number 172) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=wanaka
# checking uruzgan (city number 173) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=uruzgan
# checking mananjary (city number 174) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mananjary
# checking hasaki (city number 175) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hasaki
# checking chifeng (city number 176) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chifeng
# checking atambua (city number 177) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=atambua
# checking mahebourg (city number 178) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mahebourg
# checking barcelos (city number 179) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=barcelos
# checking teya (city number 180) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=teya
# checking ler (city number 181) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ler
# checking manicore (city number 182) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=manicore
# checking vostok (city number 183) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vostok
# checking saleaula (city number 184) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saleaula
# City not found
# checking balangiga (city number 184) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=balangiga
# checking samusu (city number 185) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=samusu
# City not found
# checking the valley (city number 185) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=the valley
# checking ilulissat (city number 186) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ilulissat
# checking carutapera (city number 187) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=carutapera
# checking wasilla (city number 188) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=wasilla
# checking grand river south east (city number 189) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=grand river south east
# City not found
# checking karratha (city number 189) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=karratha
# checking tim (city number 190) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tim
# checking celestun (city number 191) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=celestun
# checking barentsburg (city number 192) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=barentsburg
# City not found
# checking lagoa (city number 192) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lagoa
# checking nacala (city number 193) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nacala
# checking kharhial (city number 194) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kharhial
# checking esperance (city number 195) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=esperance
# checking tual (city number 196) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tual
# checking fare (city number 197) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=fare
# checking bara (city number 198) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bara
# checking namibe (city number 199) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=namibe
# checking belmonte (city number 200) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=belmonte
# checking nakamura (city number 201) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nakamura
# checking nanga eboko (city number 202) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nanga eboko
# checking khatanga (city number 203) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=khatanga
# checking bocas del toro (city number 204) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bocas del toro
# checking karakol (city number 205) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=karakol
# checking iranshahr (city number 206) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=iranshahr
# checking dogondoutchi (city number 207) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dogondoutchi
# checking clyde river (city number 208) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=clyde river
# checking ust-omchug (city number 209) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ust-omchug
# checking marang (city number 210) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=marang
# City not found
# checking damaturu (city number 210) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=damaturu
# checking dabola (city number 211) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dabola
# checking saskylakh (city number 212) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saskylakh
# checking belyy yar (city number 213) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=belyy yar
# checking valparaiso (city number 214) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=valparaiso
# checking sao filipe (city number 215) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sao filipe
# checking brae (city number 216) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=brae
# checking palabuhanratu (city number 217) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=palabuhanratu
# City not found
# checking ewa beach (city number 217) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ewa beach
# checking lompoc (city number 218) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lompoc
# checking largo (city number 219) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=largo
# checking norman wells (city number 220) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=norman wells
# checking falealupo (city number 221) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=falealupo
# City not found
# checking black river (city number 221) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=black river
# checking sanica (city number 222) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sanica
# checking chagda (city number 223) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chagda
# City not found
# checking santa cruz cabralia (city number 223) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=santa cruz cabralia
# checking guaymas (city number 224) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=guaymas
# checking chokurdakh (city number 225) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chokurdakh
# checking arraial do cabo (city number 226) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=arraial do cabo
# checking yerbogachen (city number 227) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yerbogachen
# checking shimoda (city number 228) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=shimoda
# checking maravilha (city number 229) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=maravilha
# checking deputatskiy (city number 230) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=deputatskiy
# checking bambous virieux (city number 231) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bambous virieux
# checking mariental (city number 232) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mariental
# checking curuguaty (city number 233) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=curuguaty
# checking airai (city number 234) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=airai
# checking guelengdeng (city number 235) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=guelengdeng
# City not found
# checking banihal (city number 235) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=banihal
# checking saint-joseph (city number 236) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-joseph
# checking labuhan (city number 237) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=labuhan
# checking wuwei (city number 238) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=wuwei
# checking carnot (city number 239) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=carnot
# checking tevriz (city number 240) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tevriz
# checking panguna (city number 241) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=panguna
# checking kamaishi (city number 242) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kamaishi
# checking iskateley (city number 243) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=iskateley
# checking neuquen (city number 244) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=neuquen
# checking qaanaaq (city number 245) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=qaanaaq
# checking changchun (city number 246) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=changchun
# checking iqaluit (city number 247) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=iqaluit
# checking ismailia (city number 248) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ismailia
# checking kenai (city number 249) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kenai
# checking samana (city number 250) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=samana
# checking gafargaon (city number 251) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=gafargaon
# checking katsuura (city number 252) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=katsuura
# checking jinji (city number 253) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=jinji
# checking havre-saint-pierre (city number 254) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=havre-saint-pierre
# checking shaoguan (city number 255) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=shaoguan
# checking dalbandin (city number 256) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dalbandin
# checking darnah (city number 257) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=darnah
# checking tougue (city number 258) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tougue
# checking petropavlovsk-kamchatskiy (city number 259) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=petropavlovsk-kamchatskiy
# checking erenhot (city number 260) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=erenhot
# checking lianyuan (city number 261) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lianyuan
# checking codrington (city number 262) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=codrington
# checking xai-xai (city number 263) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=xai-xai
# checking half moon bay (city number 264) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=half moon bay
# checking parana (city number 265) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=parana
# checking pangnirtung (city number 266) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pangnirtung
# checking sibenik (city number 267) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sibenik
# checking longyearbyen (city number 268) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=longyearbyen
# checking xixiang (city number 269) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=xixiang
# checking coquimbo (city number 270) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=coquimbo
# checking mehran (city number 271) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mehran
# checking srednekolymsk (city number 272) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=srednekolymsk
# checking antofagasta (city number 273) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=antofagasta
# checking narsaq (city number 274) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=narsaq
# checking mgandu (city number 275) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mgandu
# checking baisha (city number 276) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=baisha
# checking novyy urengoy (city number 277) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=novyy urengoy
# checking mahanje (city number 278) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mahanje
# City not found
# checking faanui (city number 278) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=faanui
# checking barbacoas (city number 279) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=barbacoas
# checking taonan (city number 280) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=taonan
# checking ust-nera (city number 281) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ust-nera
# checking koupela (city number 282) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=koupela
# checking nha trang (city number 283) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nha trang
# checking sabang (city number 284) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sabang
# ...
# checking yeppoon (city number 414) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=yeppoon
# checking santa rosa (city number 415) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=santa rosa
# checking vanimo (city number 416) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vanimo
# checking dolores (city number 417) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dolores
# checking longlac (city number 418) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=longlac
# City not found
# checking rio brilhante (city number 418) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=rio brilhante
# checking saint-paul (city number 419) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-paul
# checking iberia (city number 420) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=iberia
# checking williston (city number 421) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=williston
# checking aksu (city number 422) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=aksu
# checking salisbury (city number 423) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=salisbury
# checking ruiz (city number 424) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ruiz
# checking manbij (city number 425) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=manbij
# checking lourdes (city number 426) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lourdes
# checking karaul (city number 427) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=karaul
# City not found
# checking paciran (city number 427) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=paciran
# checking kaa-khem (city number 428) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kaa-khem
# checking riyadh (city number 429) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=riyadh
# checking delta (city number 430) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=delta
# checking igarape-acu (city number 431) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=igarape-acu
# City not found
# checking alofi (city number 431) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=alofi
# checking chulman (city number 432) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chulman
# checking meulaboh (city number 433) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=meulaboh
# checking lauria (city number 434) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lauria
# checking pakokku (city number 435) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pakokku
# checking balila (city number 436) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=balila
# checking obera (city number 437) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=obera
# checking korgen (city number 438) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=korgen
# checking aporawan (city number 439) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=aporawan
# City not found
# checking kaitangata (city number 439) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kaitangata
# checking abnub (city number 440) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=abnub
# checking toliary (city number 441) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=toliary
# City not found
# checking mandiana (city number 441) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=mandiana
# checking dukat (city number 442) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dukat
# checking fortuna (city number 443) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=fortuna
# checking pemangkat (city number 444) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=pemangkat
# City not found
# checking dwarka (city number 444) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dwarka
# checking kishanganj (city number 445) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kishanganj
# checking nizwa (city number 446) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nizwa
# checking sheboygan (city number 447) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sheboygan
# checking bargal (city number 448) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bargal
# City not found
# checking prince rupert (city number 448) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=prince rupert
# checking malinovoye ozero (city number 449) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=malinovoye ozero
# checking chiredzi (city number 450) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=chiredzi
# checking lagos (city number 451) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=lagos
# checking oistins (city number 452) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=oistins
# checking buraydah (city number 453) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=buraydah
# checking imbituba (city number 454) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=imbituba
# checking saint anthony (city number 455) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint anthony
# checking moreira sales (city number 456) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=moreira sales
# checking nampula (city number 457) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nampula
# checking karatau (city number 458) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=karatau
# checking macieira de cambra (city number 459) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=macieira de cambra
# checking meadow lake (city number 460) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=meadow lake
# checking salamiyah (city number 461) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=salamiyah
# checking bismil (city number 462) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bismil
# checking oliver (city number 463) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=oliver
# checking bereznik (city number 464) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bereznik
# checking fuyang (city number 465) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=fuyang
# checking bacuit (city number 466) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bacuit
# City not found
# checking ledyard (city number 466) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ledyard
# checking takoradi (city number 467) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=takoradi
# checking olafsvik (city number 468) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=olafsvik
# City not found
# checking akyab (city number 468) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=akyab
# City not found
# checking san andres (city number 468) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=san andres
# checking uarini (city number 469) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=uarini
# checking hays (city number 470) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hays
# checking ashcroft (city number 471) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ashcroft
# checking bonavista (city number 472) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=bonavista
# checking ozinki (city number 473) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=ozinki
# checking vanavara (city number 474) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vanavara
# checking kozmodemyansk (city number 475) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kozmodemyansk
# checking veraval (city number 476) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=veraval
# checking kuche (city number 477) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kuche
# City not found
# checking manjacaze (city number 477) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=manjacaze
# checking dargaville (city number 478) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=dargaville
# checking whitehorse (city number 479) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=whitehorse
# checking sirjan (city number 480) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=sirjan
# checking peleduy (city number 481) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=peleduy
# checking nanakuli (city number 482) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=nanakuli
# checking tyukhtet (city number 483) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tyukhtet
# checking hlotse (city number 484) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=hlotse
# City not found
# checking luwuk (city number 484) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=luwuk
# checking najran (city number 485) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=najran
# checking paamiut (city number 486) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=paamiut
# checking vila velha (city number 487) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=vila velha
# checking kangaatsiaq (city number 488) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kangaatsiaq
# checking taburi (city number 489) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=taburi
# City not found
# checking port blair (city number 489) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=port blair
# checking monteiro (city number 490) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=monteiro
# checking kidal (city number 491) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kidal
# checking marsh harbour (city number 492) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=marsh harbour
# checking esso (city number 493) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=esso
# checking buncrana (city number 494) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=buncrana
# checking saint-medard-en-jalles (city number 495) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=saint-medard-en-jalles
# checking kang (city number 496) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=kang
# checking fort wellington (city number 497) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=fort wellington
# checking areosa (city number 498) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=areosa
# checking tura (city number 499) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tura
# checking tautira (city number 500) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=tautira
# checking comodoro rivadavia (city number 501) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=comodoro rivadavia
# checking batticaloa (city number 502) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=batticaloa
# checking waingapu (city number 503) at url http://api.openweathermap.org/data/2.5/weather?appid=febde43dfe4affe5e81fe677f8e0a7e3&units=metric&q=waingapu

# %% [markdown]
# #### Create and save a data frame with the query response data

# %%
# Use a dictionary to create a Pandas DataFrame with the data
weather_dict = {
    "City": city_name,
    "Latitude": lat,
    "Max Temperature": maxtemp,
    "Humidity": humid,
    "Cloudiness": cloud,
    "Wind Speed": wind_spd
}
weather_data = pd.DataFrame(weather_dict)

# Translate temperature in Celsius to Fahrenheit
weather_data["Max Temperature"] = weather_data["Max Temperature"]*1.8 + 32

# Create the CSV and display the dataframe
weather_data.to_csv('output/Weather_data.csv')
weather_data.head()
# Out:
#              City  Latitude  Max Temperature  Humidity  Cloudiness  Wind Speed
# 0         Pushkar     26.49           61.790        44           0        1.24
# 1      Debre Sina      9.85           44.510        76           0        0.76
# 2  Vestmannaeyjar     63.44           44.240        94          92       10.84
# 3      Nikolskoye     59.70           37.004        93           0        2.00
# 4       Carnarvon    -30.97           58.190        73           0        3.64

# %% [markdown]
# #### Build four scatter plots, one for each type of data versus latitude

# %% [markdown]
# #### Temperature versus latitude plot

# %%
# Build the scatter plot
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], marker="o", edgecolor="black", linewidths=1, 
            alpha=0.8)

# Incorporate the other graph properties
plt.title("Maximum Temperature vs. Latitude around the Globe")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/MaxTemp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Humidity versus latitude plot

# %%
# Build the scatter plot
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o", edgecolor="black", linewidths=1, 
            alpha=0.8)

# Incorporate the other graph properties
plt.title("Humidity vs. Latitude around the Globe")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Cloudiness versus latitude plot

# %%
# Build the scatter plot
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o", edgecolor="black", linewidths=1, 
            alpha=0.8)

# Incorporate the other graph properties
plt.title("Cloudiness vs. Latitude around the Globe")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e82990f650b> in <module>
#       1 # Build the scatter plot
# ----> 2 plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o", edgecolor="black", linewidths=1,
#       3             alpha=0.8)
#       4
#       5 # Incorporate the other graph properties
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### Wind speed versus latitude plot

# %%
# Build the scatter plot
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o", edgecolor="black", linewidths=1, 
            alpha=0.8)

# Incorporate the other graph properties
plt.title("Wind Speed vs. Latitude around the Globe")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Wind Speed_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-df43f1425411> in <module>
#       1 # Build the scatter plot
# ----> 2 plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], marker="o", edgecolor="black", linewidths=1,
#       3             alpha=0.8)
#       4
#       5 # Incorporate the other graph properties
#
# NameError: name 'weather_data' is not defined

# %% [markdown]
# #### Three Conclusions

# %% [markdown]
# ##### 1. Clearly, temperature goes up as you get closer to the equator. The temperature data bends in an arc, from 30 degrees Fahrenheit at -60 degrees latitude to 85 degrees at the equator to 30 degrees at 80 degrees latitude.

# %% [markdown]
# ###### 2. Wind Speed and Humidity appear normally distributed, with a low wind speed and a high humidity being the consistent realities for this data set. The global humidity seems to have a median of around 85%, and wind speed seems to be a median of around 1.5-2.5%.

# %% [markdown]
# ##### 3. Simply looking at cloudiness versus latitude does not tell us much more than that it appears random: cloudiness may have a relationship with other data (like if it is a coastal or non-coastal city, etc.) but there does not seem to be a relationship with latitude.
